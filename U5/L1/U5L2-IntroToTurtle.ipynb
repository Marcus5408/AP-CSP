# %%
# 7

import turtle

tony = turtle.Turtle()

tony.forward(80)
tony.left(90)
tony.forward(80)
tony.left(90)
tony.forward(80)
tony.left(90)
tony.forward(80)

turtle.done()

# %%
# 8

import turtle

tony = turtle.Turtle()

tony.forward(100)
tony.left(120)
tony.forward(100)
tony.left(120)
tony.forward(100)

turtle.done()

# %%
# 9

import turtle

tony = turtle.Turtle()

tony.forward(40)
tony.left(45)
tony.forward(40)
tony.left(45)
tony.forward(40)
tony.left(45)
tony.forward(40)
tony.left(45)
tony.forward(40)

turtle.done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 5
#       1 # 9
#       3 import turtle
# ----> 5 tony = turtle.Turtle()
#       7 tony.forward(40)
#       8 tony.left(45)
#
# File C:\Python312\Lib\turtle.py:3876, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3874 if Turtle._screen is None:
#    3875     Turtle._screen = Screen()
# -> 3876 RawTurtle.__init__(self, Turtle._screen,
#    3877                    shape=shape,
#    3878                    undobuffersize=undobuffersize,
#    3879                    visible=visible)
#
# File C:\Python312\Lib\turtle.py:2565, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2563 self._undobuffersize = undobuffersize
#    2564 self.undobuffer = Tbuffer(undobuffersize)
# -> 2565 self._update()
#
# File C:\Python312\Lib\turtle.py:2668, in RawTurtle._update(self)
#    2666     return
# ...
